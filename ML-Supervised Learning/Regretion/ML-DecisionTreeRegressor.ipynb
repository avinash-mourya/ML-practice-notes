# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')
data.sort_values(by='MEDV',inplace=True)
data.loc[(data['MEDV']>14)&(data['MEDV']<25)]
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 455   4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 431  10.06230   0.0  18.10     0  0.584  6.833  94.3  2.0882   24  666
# 448   9.32909   0.0  18.10     0  0.713  6.185  98.7  2.2616   24  666
# 421   7.02259   0.0  18.10     0  0.718  6.006  95.3  1.8746   24  666
# 433   5.58107   0.0  18.10     0  0.713  6.436  87.9  2.3158   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 43    0.15936   0.0   6.91     0  0.448  6.211   6.5  5.7209    3  233
# 289   0.04297  52.5   5.32     0  0.405  6.565  22.9  7.3172    6  293
# 251   0.21409  22.0   5.86     0  0.431  6.438   8.9  7.3967    7  330
# 82    0.03659  25.0   4.86     0  0.426  6.302  32.2  5.4007    4  281
# 300   0.04417  70.0   2.24     0  0.400  6.871  47.4  7.8278    5  358
#
#      PTRATIO       B  LSTAT  MEDV
# 455     20.2   50.92  18.13  14.1
# 431     20.2   81.33  19.69  14.1
# ...

# %%
data.loc[data['RM']== 6.208]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
data.loc[data['RM'].isnull()]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 10   0.22489  12.5   7.87     0  0.524 NaN  94.3  6.3467    5  311     15.2
# 135  0.55778   0.0  21.89     0  0.624 NaN  98.2  2.1107    4  437     21.2
# 35   0.06417   0.0   5.96     0  0.499 NaN  68.2  3.3603    5  279     19.2
# 96   0.11504   0.0   2.89     0  0.445 NaN  69.6  3.4952    2  276     18.0
# 63   0.12650  25.0   5.13     0  0.453 NaN  43.4  7.9809    8  284     19.7
#
#           B  LSTAT  MEDV
# 10   392.52  20.45  15.0
# 135  394.67  16.96  18.1
# 35   396.90   9.68  18.9
# 96   391.83  11.34  21.4
# 63   395.58   9.50  25.0

# %%
median = {'RM':data.RM.median()}
data = data.fillna(6.000)
data = data.dropna(subset=['RM'],axis=0)
data.loc[[10,135,35,96,63],:]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX   RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 10   0.22489  12.5   7.87     0  0.524  6.0  94.3  6.3467    5  311     15.2
# 135  0.55778   0.0  21.89     0  0.624  6.0  98.2  2.1107    4  437     21.2
# 35   0.06417   0.0   5.96     0  0.499  6.0  68.2  3.3603    5  279     19.2
# 96   0.11504   0.0   2.89     0  0.445  6.0  69.6  3.4952    2  276     18.0
# 63   0.12650  25.0   5.13     0  0.453  6.0  43.4  7.9809    8  284     19.7
#
#           B  LSTAT  MEDV
# 10   392.52  20.45  15.0
# 135  394.67  16.96  18.1
# 35   396.90   9.68  18.9
# 96   391.83  11.34  21.4
# 63   395.58   9.50  25.0

# %%
data.corr()#['INDUS','LSTAT','PTRATIO','RAD','TAX','CRIM']
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.217503  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311261 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.390342  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.092452  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.300229  0.731470
# RM      -0.217503  0.311261 -0.390342  0.092452 -0.300229  1.000000 -0.240317
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240317  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.200462 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.207998  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.289784  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.356157  0.261515
# ...

# %%
# clean_data = data.drop(columns=['INDUS','LSTAT','PTRATIO','RAD','TAX','CRIM','NOX','AGE'])
# clean_data

# %%
data.RM.mode()
# Out:
# 0    6.0
# dtype: float64

# %%
# # from pandas.plotting import scatter_matrix
# plt.figure(figsize=(10,10))
# # scatter_matrix(clean_data)
# sns.pairplot(data)
# plt.show()

# %%
plt.scatter(data.loc[:,"RM"],data.loc[:,"MEDV"])

# %%
X = data.iloc[:,0:13].values
Y = data.iloc[:,13].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor,plot_tree
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score,mean_squared_error

# %%
train_x,test_x,train_y,test_y = train_test_split(X,Y,test_size=0.3,random_state=5)

# %%
# DCR = KNeighborsRegressor()

# %%
DCR = DecisionTreeRegressor(random_state=5)

# %%
DCR.fit(train_x,train_y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=5, splitter='best')

# %%
pred_y = DCR.predict(test_x)

# %%
test_y
# Out:
# array([20.4, 22.4, 14.8, 24.8, 21.8, 29.6, 50. , 20.6, 16.1, 37.9, 15.2,
#        23.7, 22.9, 22.8, 21.8, 23.9, 29. , 18.2, 50. , 28.7, 50. , 17.2,
#        20.3, 23.1, 22.1, 33. , 23.1, 16.3, 23.5, 24.1, 16.7, 48.8, 27.1,
#        34.6, 22.7, 17.2, 20.6, 30.3, 21.5, 11.8, 27. , 17.7, 20.3, 34.9,
#        22.5, 22.6, 29.1, 16.7, 18.2, 17.6, 15.6, 23.3, 13.9, 11. , 18.3,
#        13.1, 15.2, 34.9, 22.5, 12.7, 50. , 19.1, 17.1, 18.4, 24.4, 28.1,
#        10.4, 12. , 13.8, 48.3, 41.7, 22.9, 12.7, 28.7, 28.5, 24.1, 18.9,
#        18.1, 21.6, 29.9, 37.6, 18.6, 20.2, 31.6, 13.5, 33.3, 50. , 26.7,
#        22.6, 24.1, 19.4,  9.5, 43.1, 32.7, 23.3, 13. , 17.4, 24. , 20. ,
#        18.4, 43.5, 21. , 10.9, 22. , 29.6, 50. , 28. , 24.7, 19.7, 22.9,
#        23.8, 20.5, 27.1, 19.6, 33.4, 17.8, 19.3, 12.6,  7.4, 20.9, 23.8,
#        22.8, 23.6, 23.4, 13.1, 15.3, 36.2, 20.1, 16.4, 19.5, 18.6, 20.1,
#        32.4, 17.5, 25. , 23.1, 39.8, 26.4, 13.4, 19.4, 23. , 18.4,  8.7,
# ...

# %%
pred_y
# Out:
# array([23.1, 19.3, 15.6, 28.6, 19.5, 20.8, 42.3, 24.5, 19.9, 37.2,  7. ,
#        26.5, 22. , 30.1, 20. , 22.9, 33.1, 20.6, 50. , 30.1, 36. , 17.9,
#        21.4, 21.7, 22.8, 28.2, 21.7, 17.9, 24.6, 26.6, 15.4, 33.2, 15. ,
#        32.2, 16.2, 17.1, 18.7, 32.2, 18.7, 14.6, 21.6, 21.7, 19.4, 33.1,
#        24.6, 22. , 31.1, 16.1, 19.6, 17.1, 14.9, 25. , 15.6, 23.2, 19.3,
#        15.4, 14.9, 32.2, 19.8, 14.6, 50. , 13.6, 15.4, 14.9, 21.7, 29.1,
#        27.5, 17.9, 14.6, 46. , 45.4, 18.9, 14.1, 33.2, 35.4, 22. , 17.1,
#        20. , 22.9, 29. , 44.8, 16.1, 23.2, 31.7, 13.6, 32. , 50. , 27.5,
#        21.5, 29.1, 18.5, 12.8, 36.1, 31.7, 22. , 13.6, 18.7, 31.1, 22.2,
#        18.2, 50. , 25.1, 10.2, 21.9, 33.1, 43.8, 26.6, 20.7, 18.9, 22. ,
#        17.4, 18.9, 22. , 21.4, 35.4, 27.5, 20.1, 15.4,  7.2, 11.9, 25. ,
#        31.1, 33.2, 22.2, 14.3, 19.6, 33.4, 19.9, 16.1, 19.9, 22.2, 22.2,
#        30.8, 17.1, 31.7, 25. , 35.2, 23.1,  9.7, 11.9, 19.6, 18.7, 10.8,
# ...

# %%
r2_score(test_y,pred_y)
# Out:
# 0.7854158261504225

# %%
mean_squared_error(test_y,pred_y)
# Out:
# 18.61473684210526

# %% [markdown]
# # DecisionTree Visulization part

# %%
plt.figure(figsize=(30,30),facecolor='m',edgecolor="red")
plot_tree(DCR.fit(train_x,train_y),rotate=True,max_depth=5,rounded=True,fontsize=20,impurity=True,node_ids=False, proportion=False,precision=2,filled=True)
plt.show()

# %%
train_x.shape
# Out:
# (354, 13)

# %% [markdown]
# # Ann - artificial neural network

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(units=13,activation='relu',input_dim=13))
model.add(Dense(128,activation='relu'))
model.add(Dense(62,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_20 (Dense)             (None, 13)                182
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               1792
# _________________________________________________________________
# dense_22 (Dense)             (None, 62)                7998
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 63
# ...
# Total params: 10,035
# Trainable params: 10,035
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_x,train_y,batch_size=100,epochs=150)
# Out:
# Train on 354 samples
# Epoch 1/150
# 354/354 [==============================] - 0s 1ms/sample - loss: 595.9146 - mse: 595.9146
# Epoch 2/150
# 354/354 [==============================] - 0s 48us/sample - loss: 347.7395 - mse: 347.7395
# Epoch 3/150
# 354/354 [==============================] - 0s 45us/sample - loss: 186.0947 - mse: 186.0947
# Epoch 4/150
# 354/354 [==============================] - 0s 45us/sample - loss: 128.3058 - mse: 128.3057
# Epoch 5/150
# 354/354 [==============================] - 0s 34us/sample - loss: 130.0632 - mse: 130.0632
# Epoch 6/150
# 354/354 [==============================] - 0s 45us/sample - loss: 86.9787 - mse: 86.9787
# Epoch 7/150
# 354/354 [==============================] - 0s 45us/sample - loss: 106.9506 - mse: 106.9506
# Epoch 8/150
# 354/354 [==============================] - 0s 45us/sample - loss: 79.1053 - mse: 79.1053
# Epoch 9/150
# 354/354 [==============================] - 0s 45us/sample - loss: 77.9094 - mse: 77.9094
# Epoch 10/150
# ...

# %%
pred_Y = model.predict(test_x)

# %%
y = pred_Y.ravel()

# %%
y
# Out:
# array([28.797506, 22.349806, 17.829168, 30.802404, 36.19922 , 31.416624,
#        37.95445 , 33.304806, 20.227678, 41.780315, 24.01325 , 37.406773,
#        28.35945 , 29.512426, 25.683584, 27.729448, 34.515347, 26.287867,
#        36.162445, 28.102468, 31.763502, 16.42818 , 25.351324, 27.660986,
#        31.624537, 34.45886 , 20.476522, 23.352636, 34.934208, 29.800734,
#        26.955122, 37.310944, 23.428988, 30.950502, 28.724554, 22.241858,
#        28.419691, 26.844568, 24.117956, 18.053995, 33.044373, 27.834631,
#        23.28628 , 40.28307 , 32.402794, 28.543867, 33.18195 , 22.762037,
#        25.571856, 23.30187 , 20.425539, 27.13851 , 17.448706, 15.704774,
#        24.418627, 24.21282 , 24.208456, 34.1861  , 20.669485, 24.052198,
#        38.369022, 21.085775, 21.139067, 25.277311, 25.792242, 26.438757,
#        17.285383, 18.103964, 16.77513 , 33.195328, 35.341564, 26.406286,
#        17.174028, 31.986486, 39.84256 , 30.482054, 24.592371, 24.081156,
# ...

# %%
test_y.shape
# Out:
# (152,)

# %%
model.evaluate(test_x,test_y,batch_size=15)
# Out:
# 152/1 [===============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
help(model)
# Out:
# Help on Sequential in module tensorflow.python.keras.engine.sequential object:
#
# class Sequential(tensorflow.python.keras.engine.training.Model)
#  |  Sequential(layers=None, name=None)
#  |
#  |  Linear stack of layers.
#  |
#  |  Arguments:
#  |      layers: list of layers to add to the model.
#  |
#  |  Example:
#  |
#  |  ```python
#  |  # Optionally, the first layer can receive an `input_shape` argument:
#  |  model = Sequential()
#  |  model.add(Dense(32, input_shape=(500,)))
#  |  # Afterwards, we do automatic shape inference:
#  |  model.add(Dense(32))
#  |
#  |  # This is identical to the following:
#  |  model = Sequential()
#  |  model.add(Dense(32, input_dim=500))
#  |
#  |  # And to the following:
#  |  model = Sequential()
#  |  model.add(Dense(32, batch_input_shape=(None, 500)))
#  |
#  |  # Note that you can also omit the `input_shape` argument:
#  |  # In that case the model gets built the first time you call `fit` (or other
# ...
