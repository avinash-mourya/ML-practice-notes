# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
pd.read_excel('iris.xlsx',sheet_name=1,header=1)
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa       Unnamed: 5           Unnamed: 6  \
# 0    4.9  3.0  1.4  0.2     Iris-setosa       Row Labels  Sum of petal_length
# 1    4.7  3.2  1.3  0.2     Iris-setosa      Iris-setosa                 73.2
# 2    4.6  3.1  1.5  0.2     Iris-setosa  Iris-versicolor                  213
# 3    5.0  3.6  1.4  0.2     Iris-setosa   Iris-virginica                277.6
# 4    5.4  3.9  1.7  0.4     Iris-setosa      Grand Total                563.8
# ..   ...  ...  ...  ...             ...              ...                  ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica              NaN                  NaN
# 145  6.3  2.5  5.0  1.9  Iris-virginica              NaN                  NaN
# 146  6.5  3.0  5.2  2.0  Iris-virginica              NaN                  NaN
# 147  6.2  3.4  5.4  2.3  Iris-virginica              NaN                  NaN
# 148  5.9  3.0  5.1  1.8  Iris-virginica              NaN                  NaN
#
# ...
